# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=     1 ,  
                out_channels=    32 ,
                kernel_size=     (7,7) ,
                stride=          1 ,
                padding=         3 ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=5,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn,device):
    global prediction
    cnn.eval()
    y_pre = cnn(test_x.to(device))
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.cpu().numpy()
    correct  = np.sum(prediction == test_y)
    cnn.train()
    return correct / 500.0


def train(cnn,device):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_).to(device),Variable(y_).to(device)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn,device) ,"=" * 10 )

if __name__ == '__main__':
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)
    cnn = CNN().to(device)
    train(cnn,device)
# Out:
# e:\Anaconda3\Anaconda3_file\envs\pytorch0\lib\site-packages\torchvision\datasets\mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\26016\AppData\Local\Temp\ipykernel_10224\59829302.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# e:\Anaconda3\Anaconda3_file\envs\pytorch0\lib\site-packages\torchvision\datasets\mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# cuda
# C:\Users\26016\AppData\Local\Temp\ipykernel_10224\59829302.py:72: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.47 ==========
# ========== 40 ===== ===== test accuracy is  0.368 ==========
# ========== 60 ===== ===== test accuracy is  0.528 ==========
# ========== 80 ===== ===== test accuracy is  0.626 ==========
# ========== 100 ===== ===== test accuracy is  0.656 ==========
# ========== 120 ===== ===== test accuracy is  0.686 ==========
# ========== 140 ===== ===== test accuracy is  0.7 ==========
# ========== 160 ===== ===== test accuracy is  0.764 ==========
# ========== 180 ===== ===== test accuracy is  0.754 ==========
# ========== 200 ===== ===== test accuracy is  0.818 ==========
# ========== 220 ===== ===== test accuracy is  0.852 ==========
# ========== 240 ===== ===== test accuracy is  0.87 ==========
# ========== 260 ===== ===== test accuracy is  0.864 ==========
# ========== 280 ===== ===== test accuracy is  0.886 ==========
# ========== 300 ===== ===== test accuracy is  0.882 ==========
# ========== 320 ===== ===== test accuracy is  0.914 ==========
# ========== 340 ===== ===== test accuracy is  0.892 ==========
# ========== 360 ===== ===== test accuracy is  0.908 ==========
# ========== 380 ===== ===== test accuracy is  0.914 ==========
# ========== 400 ===== ===== test accuracy is  0.922 ==========
# ========== 420 ===== ===== test accuracy is  0.916 ==========
# ========== 440 ===== ===== test accuracy is  0.914 ==========
# ========== 460 ===== ===== test accuracy is  0.92 ==========
# ========== 480 ===== ===== test accuracy is  0.918 ==========
# ========== 500 ===== ===== test accuracy is  0.928 ==========
# ========== 520 ===== ===== test accuracy is  0.928 ==========
# ========== 540 ===== ===== test accuracy is  0.924 ==========
# ========== 560 ===== ===== test accuracy is  0.934 ==========
# ========== 580 ===== ===== test accuracy is  0.932 ==========
# ========== 600 ===== ===== test accuracy is  0.928 ==========
# ========== 620 ===== ===== test accuracy is  0.93 ==========
# ========== 640 ===== ===== test accuracy is  0.934 ==========
# ========== 660 ===== ===== test accuracy is  0.928 ==========
# ========== 680 ===== ===== test accuracy is  0.932 ==========
# ========== 700 ===== ===== test accuracy is  0.934 ==========
# ========== 720 ===== ===== test accuracy is  0.94 ==========
# ========== 740 ===== ===== test accuracy is  0.942 ==========
# ========== 760 ===== ===== test accuracy is  0.942 ==========
# ========== 780 ===== ===== test accuracy is  0.942 ==========
# ========== 800 ===== ===== test accuracy is  0.954 ==========
# ========== 820 ===== ===== test accuracy is  0.954 ==========
# ========== 840 ===== ===== test accuracy is  0.946 ==========
# ========== 860 ===== ===== test accuracy is  0.95 ==========
# ========== 880 ===== ===== test accuracy is  0.952 ==========
# ========== 900 ===== ===== test accuracy is  0.952 ==========
# ========== 920 ===== ===== test accuracy is  0.948 ==========
# ========== 940 ===== ===== test accuracy is  0.95 ==========
# ========== 960 ===== ===== test accuracy is  0.95 ==========
# ========== 980 ===== ===== test accuracy is  0.95 ==========
# ========== 1000 ===== ===== test accuracy is  0.954 ==========
# ========== 1020 ===== ===== test accuracy is  0.95 ==========
# ========== 1040 ===== ===== test accuracy is  0.95 ==========
# ========== 1060 ===== ===== test accuracy is  0.952 ==========
# ========== 1080 ===== ===== test accuracy is  0.956 ==========
# ========== 1100 ===== ===== test accuracy is  0.962 ==========
# ========== 1120 ===== ===== test accuracy is  0.956 ==========
# ========== 1140 ===== ===== test accuracy is  0.946 ==========
# ========== 1160 ===== ===== test accuracy is  0.954 ==========
# ========== 1180 ===== ===== test accuracy is  0.96 ==========
# ========== 20 ===== ===== test accuracy is  0.956 ==========
# ========== 40 ===== ===== test accuracy is  0.966 ==========
# ========== 60 ===== ===== test accuracy is  0.964 ==========
# ========== 80 ===== ===== test accuracy is  0.956 ==========
# ========== 100 ===== ===== test accuracy is  0.968 ==========
# ========== 120 ===== ===== test accuracy is  0.966 ==========
# ========== 140 ===== ===== test accuracy is  0.966 ==========
# ========== 160 ===== ===== test accuracy is  0.96 ==========
# ========== 180 ===== ===== test accuracy is  0.966 ==========
# ========== 200 ===== ===== test accuracy is  0.96 ==========
# ========== 220 ===== ===== test accuracy is  0.962 ==========
# ========== 240 ===== ===== test accuracy is  0.962 ==========
# ========== 260 ===== ===== test accuracy is  0.962 ==========
# ========== 280 ===== ===== test accuracy is  0.966 ==========
# ========== 300 ===== ===== test accuracy is  0.966 ==========
# ========== 320 ===== ===== test accuracy is  0.962 ==========
# ========== 340 ===== ===== test accuracy is  0.966 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.966 ==========
# ========== 400 ===== ===== test accuracy is  0.97 ==========
# ========== 420 ===== ===== test accuracy is  0.968 ==========
# ========== 440 ===== ===== test accuracy is  0.97 ==========
# ========== 460 ===== ===== test accuracy is  0.966 ==========
# ========== 480 ===== ===== test accuracy is  0.966 ==========
# ========== 500 ===== ===== test accuracy is  0.968 ==========
# ========== 520 ===== ===== test accuracy is  0.974 ==========
# ========== 540 ===== ===== test accuracy is  0.968 ==========
# ========== 560 ===== ===== test accuracy is  0.964 ==========
# ========== 580 ===== ===== test accuracy is  0.966 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.968 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.972 ==========
# ========== 680 ===== ===== test accuracy is  0.964 ==========
# ========== 700 ===== ===== test accuracy is  0.968 ==========
# ========== 720 ===== ===== test accuracy is  0.968 ==========
# ========== 740 ===== ===== test accuracy is  0.96 ==========
# ========== 760 ===== ===== test accuracy is  0.976 ==========
# ========== 780 ===== ===== test accuracy is  0.972 ==========
# ========== 800 ===== ===== test accuracy is  0.97 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.96 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.964 ==========
# ========== 900 ===== ===== test accuracy is  0.974 ==========
# ========== 920 ===== ===== test accuracy is  0.974 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.97 ==========
# ========== 980 ===== ===== test accuracy is  0.978 ==========
# ========== 1000 ===== ===== test accuracy is  0.978 ==========
# ========== 1020 ===== ===== test accuracy is  0.978 ==========
# ========== 1040 ===== ===== test accuracy is  0.974 ==========
# ========== 1060 ===== ===== test accuracy is  0.978 ==========
# ========== 1080 ===== ===== test accuracy is  0.972 ==========
# ========== 1100 ===== ===== test accuracy is  0.978 ==========
# ========== 1120 ===== ===== test accuracy is  0.98 ==========
# ========== 1140 ===== ===== test accuracy is  0.968 ==========
# ========== 1160 ===== ===== test accuracy is  0.978 ==========
# ========== 1180 ===== ===== test accuracy is  0.974 ==========
# ========== 20 ===== ===== test accuracy is  0.978 ==========
# ========== 40 ===== ===== test accuracy is  0.974 ==========
# ========== 60 ===== ===== test accuracy is  0.976 ==========
# ========== 80 ===== ===== test accuracy is  0.974 ==========
# ========== 100 ===== ===== test accuracy is  0.978 ==========
# ========== 120 ===== ===== test accuracy is  0.976 ==========
# ========== 140 ===== ===== test accuracy is  0.972 ==========
# ========== 160 ===== ===== test accuracy is  0.976 ==========
# ========== 180 ===== ===== test accuracy is  0.974 ==========
# ========== 200 ===== ===== test accuracy is  0.972 ==========
# ========== 220 ===== ===== test accuracy is  0.978 ==========
# ========== 240 ===== ===== test accuracy is  0.978 ==========
# ========== 260 ===== ===== test accuracy is  0.976 ==========
# ========== 280 ===== ===== test accuracy is  0.976 ==========
# ========== 300 ===== ===== test accuracy is  0.978 ==========
# ========== 320 ===== ===== test accuracy is  0.972 ==========
# ========== 340 ===== ===== test accuracy is  0.976 ==========
# ========== 360 ===== ===== test accuracy is  0.976 ==========
# ========== 380 ===== ===== test accuracy is  0.976 ==========
# ========== 400 ===== ===== test accuracy is  0.972 ==========
# ========== 420 ===== ===== test accuracy is  0.98 ==========
# ========== 440 ===== ===== test accuracy is  0.974 ==========
# ========== 460 ===== ===== test accuracy is  0.974 ==========
# ========== 480 ===== ===== test accuracy is  0.97 ==========
# ========== 500 ===== ===== test accuracy is  0.976 ==========
# ========== 520 ===== ===== test accuracy is  0.978 ==========
# ========== 540 ===== ===== test accuracy is  0.978 ==========
# ========== 560 ===== ===== test accuracy is  0.976 ==========
# ========== 580 ===== ===== test accuracy is  0.978 ==========
# ========== 600 ===== ===== test accuracy is  0.978 ==========
# ========== 620 ===== ===== test accuracy is  0.974 ==========
# ========== 640 ===== ===== test accuracy is  0.974 ==========
# ========== 660 ===== ===== test accuracy is  0.97 ==========
# ========== 680 ===== ===== test accuracy is  0.976 ==========
# ========== 700 ===== ===== test accuracy is  0.976 ==========
# ========== 720 ===== ===== test accuracy is  0.98 ==========
# ========== 740 ===== ===== test accuracy is  0.98 ==========
# ========== 760 ===== ===== test accuracy is  0.976 ==========
# ========== 780 ===== ===== test accuracy is  0.972 ==========
# ========== 800 ===== ===== test accuracy is  0.978 ==========
# ========== 820 ===== ===== test accuracy is  0.974 ==========
# ========== 840 ===== ===== test accuracy is  0.974 ==========
# ========== 860 ===== ===== test accuracy is  0.98 ==========
# ========== 880 ===== ===== test accuracy is  0.978 ==========
# ========== 900 ===== ===== test accuracy is  0.978 ==========
# ========== 920 ===== ===== test accuracy is  0.978 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.976 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.974 ==========
# ========== 1020 ===== ===== test accuracy is  0.98 ==========
# ========== 1040 ===== ===== test accuracy is  0.98 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.978 ==========
# ========== 1100 ===== ===== test accuracy is  0.98 ==========
# ========== 1120 ===== ===== test accuracy is  0.982 ==========
# ========== 1140 ===== ===== test accuracy is  0.982 ==========
# ========== 1160 ===== ===== test accuracy is  0.98 ==========
# ========== 1180 ===== ===== test accuracy is  0.98 ==========
